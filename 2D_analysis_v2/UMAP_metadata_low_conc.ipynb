# %%
import os
import umap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.text import Text
import seaborn as sns; sns.set_style("white")
import umap.plot
# %matplotlib inline
os.getcwd()
# Out:
# '/Users/chririn/Documents/Code/2D_analysis_v2'

# %%
def pDose(x):
    '''This is just a helper function, to compute easily log transformed concentrations used in drug discovery'''
    return(-np.log10(1e-6*x))

# %%
BaseDir = "./results/"

# %%
# Import feature data after QC
selected_df = pd.read_csv("{}colopaint44_selected_data_notMAD.csv".format(BaseDir), sep=";", index_col=0)
selected_df.head(1)
# Out:
#                      Metadata_layout_id Metadata_well_id Metadata_cmpd  \
# 0  colo44-v1-FA-P017365-CACO2-48h-P1-L1              B02        [tetr]
#
#   Metadata_batch_id Metadata_solvent  Metadata_stock_conc  \
# 0         PHB000015             dmso                 10.0
#
#   Metadata_stock_conc_unit  Metadata_cmpd_vol Metadata_cmpd_vol_unit  \
# 0                       mM                7.5                     nL
#
#    Metadata_well_vol  ...  \
# 0                 30  ...
#
#   RadialDistribution_ZernikePhase_illumSYTO_9_5_cytoplasm  \
# 0                                           0.392774
#
#   Location_MaxIntensity_Z_illumPHAandWGA_nuclei  \
# 0                                           0.0
#
#    RadialDistribution_ZernikePhase_illumMITO_8_0_nuclei  \
# 0                                           1.991515
#
#   RadialDistribution_ZernikePhase_illumPHAandWGA_6_6_cells  \
# 0                                           1.031468
#
#   Correlation_Costes_illumCONC_illumMITO_cytoplasm  \
# 0                                         0.777336
#
#   Correlation_K_illumCONC_illumMITO_nuclei  \
# 0                                 0.295102
#
#   RadialDistribution_ZernikePhase_illumPHAandWGA_6_6_cytoplasm  \
# 0                                           0.678666
#
#   AreaShape_Zernike_6_6_cells  \
# 0                   -1.301256
#
#   RadialDistribution_ZernikePhase_illumMITO_1_1_cells  \
# 0                                           2.650399
#
#   Correlation_Costes_illumCONC_illumPHAandWGA_nuclei
# 0                                                0.0
#
# [1 rows x 822 columns]

# %%
df_toplot = selected_df
df_toplot['Metadata_cmpd_conc'].loc[(df_toplot['Metadata_cmpd'] == '[dmso]')] = 0.0001
df_toplot['Metadata_inv_log_conc'] = 10 - pDose(df_toplot['Metadata_cmpd_conc'])
ListOfMetadata = list(df_toplot.columns[df_toplot.columns.str.contains("Metadata_")])
# Out:
# /var/folders/bx/43bwk4n57dj9446w1ddn_7t40000gn/T/ipykernel_93491/2355280885.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_toplot['Metadata_cmpd_conc'].loc[(df_toplot['Metadata_cmpd'] == '[dmso]')] = 0.0001

# %%
subsetDf = df_toplot[df_toplot['Metadata_cmpd_conc'] != 0.00833]
subsetDf = subsetDf[subsetDf['Metadata_cmpd_conc'] != 0.03330] # Remove lowest concentrations
subsetDf = subsetDf[subsetDf['Metadata_cmpd_conc'] != 0.1]
#subsetDf = subsetDf[subsetDf['Metadata_cmpd_conc'] != 0.333]
training_data_subset = subsetDf.drop(ListOfMetadata, axis=1).to_numpy()

# %%
## UMAP - MOA

reducer = umap.UMAP(n_components=2, n_neighbors=23, min_dist= 0.3, random_state=42)
embedding = reducer.fit_transform(training_data_subset)

fig = plt.figure()
ax = sns.scatterplot(
    x=embedding[:, 0],
    y=embedding[:, 1],
    hue=subsetDf.Metadata_moa,
    alpha=(0.7),
    marker="o",
    #size=df_toplot["Metadata_cmpd_conc"],
    #palette=pal,
    #legend=False
    )
plt.legend(bbox_to_anchor=(2.8, 1),loc='upper right')
plt.title('Moa')
# Out:
# Text(0.5, 1.0, 'Moa')

# %%
## UMAP - Class
fig = plt.figure()
ax = sns.scatterplot(
    x=embedding[:, 0],
    y=embedding[:, 1],
    hue=subsetDf.Metadata_class,
    alpha=(0.7),
    marker="o",
    #size=df_toplot["Metadata_cmpd_conc"],
    #palette=pal,
    #legend=False
    )

plt.title('Class')
# Out:
# Text(0.5, 1.0, 'Class')

# %%
## UMAP - Compound
fig = plt.figure()
ax = sns.scatterplot(
    x=embedding[:, 0],
    y=embedding[:, 1],
    hue=subsetDf.Metadata_cmpd,
    alpha=(0.7),
    marker="o",
    #size=df_toplot["Metadata_cmpd_conc"],
    #palette=pal,
    legend=False
    )
plt.title('Compound')
# Out:
# Text(0.5, 1.0, 'Compound')

# %%
# np.set_printoptions(suppress=True)
# labels = df_toplot["Metadata_cmpd_conc"].unique()
# labels = np.sort(labels)
# labels = np.delete(labels, 6)
# labels

# %%
## UMAP - conc
fig = plt.figure()
ax = sns.scatterplot(
    x=embedding[:, 0],
    y=embedding[:, 1],
    hue=subsetDf.Metadata_cmpd_conc,
    alpha=(0.7),
    marker="o",
    #size=df_toplot["Metadata_cmpd_conc"],
    palette='flare',
    #legend=False
    )
plt.legend(bbox_to_anchor=(1.2, 1),loc='upper right')
plt.title('Compound conc')
# Out:
# Text(0.5, 1.0, 'Compound conc')

# %%
## UMAP - Plate
fig = plt.figure()
ax = sns.scatterplot(
    x=embedding[:, 0],
    y=embedding[:, 1],
    hue=subsetDf.Metadata_layout_id,
    alpha=(0.7),
    marker="o",
    #size=df_toplot["Metadata_cmpd_conc"],
    #palette=pal,
    legend=False
    )

plt.title('Plate')
# Out:
# Text(0.5, 1.0, 'Plate')

# %%
## UMAP - Compound
fig = plt.figure()
ax = sns.scatterplot(
    x=embedding[:, 0],
    y=embedding[:, 1],
    hue=subsetDf.Metadata_clinical_status,
    alpha=(0.7),
    marker="o",
    #size=df_toplot["Metadata_cmpd_conc"],
    #palette=pal,
    #legend=False
    )

plt.title('clinical status')
plt.legend(bbox_to_anchor=(1.35, 1),loc='upper right')
