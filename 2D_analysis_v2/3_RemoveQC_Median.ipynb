# %%
import os
import pandas as pd 
#import numpy as np

os.getcwd()
# Out:
# '/Users/chririn/Documents/Code/2D_analysis_v2'

# %%
OutputDir = "results" # Where do you want to save the merged data csv? 
if not os.path.exists(OutputDir):
    os.makedirs(OutputDir)

# %% [markdown]
# Change these codes to: 1) Remove flagged images, 2) Adjust the metadata of my plate.

# %% [markdown]
# ## Read Feature and Layout data
# Metadata matters!

# %%
# Feature data 
BaseDir = "./ImageMedianFeatures/"
df = pd.read_csv("{}/ImageMediansAllPlatesAndAreaOccupied.csv".format(BaseDir), sep=";", index_col = 0)
df.head(1)
# Out:
#                                             ImageNumber_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                 1.0
#
#                                             ObjectNumber_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                 43.0
#
#                                             Metadata_Site_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                   1.0
#
#                                             AreaShape_Area_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                 2025.0
#
#                                             AreaShape_BoundingBoxArea_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                            2835.0
#
#                                             AreaShape_BoundingBoxMaximum_X_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                 1082.0
#
#                                             AreaShape_BoundingBoxMaximum_Y_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                  675.0
#
#                                             AreaShape_BoundingBoxMinimum_X_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                 1026.0
#
#                                             AreaShape_BoundingBoxMinimum_Y_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                  614.0
#
#                                             AreaShape_Center_X_nuclei  ...  \
# ImageID                                                                ...
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                1055.226144  ...
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_2_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.874135
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_4_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.924451
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_6_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.100064
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_8_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           1.069596
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_1_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.613667
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_3_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.042208
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_5_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.264395
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_7_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.179151
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_9_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.223107
#
#                                             AreaOccupied_AreaOccupied_cells
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                        1048837.0
#
# [1 rows x 2188 columns]

# %%
# Some necessary adaptations on the dataframe
df.drop(['Metadata_Site_nuclei','Metadata_Site_cytoplasm','Metadata_Site_cells','ImageNumber_cells','ImageNumber_cytoplasm', 'ImageNumber_nuclei'], axis=1, inplace=True) # "ImageNumber_nuclei": is 1 across the entire plate, it originates in the pipelineGUI where we run batches of 1 image only -> every image will be no. 1, "Metadata_Site_nuclei": have a new column now. 
df["plate_well"] = df.index.str[0:-2] # Well identifier accross an entire batch
df.head(1)
# Out:
#                                             ObjectNumber_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                 43.0
#
#                                             AreaShape_Area_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                 2025.0
#
#                                             AreaShape_BoundingBoxArea_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                            2835.0
#
#                                             AreaShape_BoundingBoxMaximum_X_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                 1082.0
#
#                                             AreaShape_BoundingBoxMaximum_Y_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                  675.0
#
#                                             AreaShape_BoundingBoxMinimum_X_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                 1026.0
#
#                                             AreaShape_BoundingBoxMinimum_Y_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                  614.0
#
#                                             AreaShape_Center_X_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                1055.226144
#
#                                             AreaShape_Center_Y_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                 646.953343
#
#                                             AreaShape_Compactness_nuclei  ...  \
# ImageID                                                                   ...
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                      1.178212  ...
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_4_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.924451
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_6_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.100064
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_8_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           1.069596
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_1_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.613667
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_3_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.042208
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_5_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.264395
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_7_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.179151
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_9_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.223107
#
#                                             AreaOccupied_AreaOccupied_cells  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                        1048837.0
#
#                                                                           plate_well
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02
#
# [1 rows x 2183 columns]

# %% [markdown]
# ## Remove QC flagged images

# %%
QC = pd.read_csv("./QC/colo44_Flags.csv", sep=";", index_col=0)
QC["ImageID"] = (
    QC["Metadata_Barcode"]
    + "_"
    + QC["Metadata_Well"]
    + "_"
    + QC["Metadata_Site"].astype(str)
)
QC.head(3)
# Out:
#                        Metadata_Barcode Metadata_Well  Metadata_Site  \
# 0  colo44-v1-FA-P017365-CACO2-48h-P1-L1           B02              1
# 1  colo44-v1-FA-P017365-CACO2-48h-P1-L1           B02              2
# 2  colo44-v1-FA-P017365-CACO2-48h-P1-L1           B02              3
#
#    Count_nuclei  ImageQuality_PercentMaximal_CONC  \
# 0          74.0                          0.004994
# 1         123.0                          0.004951
# 2         148.0                          0.003601
#
#    ImageQuality_PercentMaximal_HOECHST  ImageQuality_PercentMaximal_MITO  \
# 0                             0.000021                          0.198667
# 1                             0.000021                          0.003558
# 2                             0.000021                          0.000343
#
#    ImageQuality_PercentMaximal_PHAandWGA  ImageQuality_PercentMaximal_SYTO  \
# 0                               0.090964                          0.292245
# 1                               0.052533                          0.110747
# 2                               0.080097                          0.143497
#
#    OutlierScaled_FocusScore_-2.0_5.0  OutlierScaled_MeanIntensity_-2.2_4.0  \
# 0                                  0                                     0
# 1                                  0                                     0
# 2                                  0                                     0
#
#    OutlierScaled_PercentMaximal_-2.0_7.5  \
# 0                                      0
# 1                                      0
# 2                                      0
#
#    OutlierScaled_PowerLogLogSlope_-3.5_3.5  \
# 0                                        0
# 1                                        0
# 2                                        0
#
#    OutlierScaled_StdIntensity_-3.3_3.3  Total  Total.1  \
# 0                                    0      0        0
# 1                                    0      0        0
# 2                                    0      0        0
#
#                                       ImageID
# 0  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1
# 1  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_2
# 2  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_3

# %%
dfQC = df.merge(QC[['ImageID', 'Total', 'Count_nuclei']], left_on = 'ImageID', right_on = 'ImageID', how = 'left') 
dfQC = dfQC[dfQC['Total'] == 0]
dfQC.drop(["Total"], axis=1, inplace=True)
dfQC.reset_index(drop=True, inplace=True)
dfQC.head()
# Out:
#                                       ImageID  ObjectNumber_nuclei  \
# 0  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                 43.0
# 1  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_2                 68.0
# 2  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_3                 82.5
# 3  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_4                 45.5
# 4  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_5                 73.0
#
#    AreaShape_Area_nuclei  AreaShape_BoundingBoxArea_nuclei  \
# 0                 2025.0                            2835.0
# 1                 2554.0                            3450.0
# 2                 2482.5                            3421.0
# 3                 2386.5                            3400.0
# 4                 2669.0                            3720.0
#
#    AreaShape_BoundingBoxMaximum_X_nuclei  \
# 0                                 1082.0
# 1                                 1138.0
# 2                                 1216.0
# 3                                 1252.0
# 4                                  937.0
#
#    AreaShape_BoundingBoxMaximum_Y_nuclei  \
# 0                                  675.0
# 1                                 1097.0
# 2                                  882.0
# 3                                 1399.5
# 4                                 1398.0
#
#    AreaShape_BoundingBoxMinimum_X_nuclei  \
# 0                                 1026.0
# 1                                 1084.0
# 2                                 1167.5
# 3                                 1199.5
# 4                                  877.0
#
#    AreaShape_BoundingBoxMinimum_Y_nuclei  AreaShape_Center_X_nuclei  \
# 0                                  614.0                1055.226144
# 1                                 1055.0                1111.934943
# 2                                  822.0                1191.003921
# 3                                 1345.0                1225.308811
# 4                                 1331.0                 905.813101
#
#    AreaShape_Center_Y_nuclei  ...  \
# 0                 646.953343  ...
# 1                1082.774481  ...
# 2                 854.779332  ...
# 3                1372.294975  ...
# 4                1360.301875  ...
#
#    RadialDistribution_ZernikePhase_illumSYTO_8_6_cytoplasm  \
# 0                                           0.100064
# 1                                           0.351326
# 2                                           0.351749
# 3                                          -0.349219
# 4                                          -0.980890
#
#    RadialDistribution_ZernikePhase_illumSYTO_8_8_cytoplasm  \
# 0                                           1.069596
# 1                                          -0.085499
# 2                                           0.011604
# 3                                           0.103266
# 4                                           0.105943
#
#    RadialDistribution_ZernikePhase_illumSYTO_9_1_cytoplasm  \
# 0                                           0.613667
# 1                                           0.093353
# 2                                          -0.324046
# 3                                           0.792170
# 4                                           0.921220
#
#    RadialDistribution_ZernikePhase_illumSYTO_9_3_cytoplasm  \
# 0                                           0.042208
# 1                                           0.145815
# 2                                          -0.666475
# 3                                           0.642661
# 4                                          -0.967466
#
#    RadialDistribution_ZernikePhase_illumSYTO_9_5_cytoplasm  \
# 0                                          -0.264395
# 1                                          -0.352045
# 2                                           0.200152
# 3                                           0.422974
# 4                                           0.027950
#
#    RadialDistribution_ZernikePhase_illumSYTO_9_7_cytoplasm  \
# 0                                          -0.179151
# 1                                           0.699133
# 2                                           0.059205
# 3                                          -0.170183
# 4                                           0.595936
#
#    RadialDistribution_ZernikePhase_illumSYTO_9_9_cytoplasm  \
# 0                                           0.223107
# 1                                           0.478048
# 2                                           0.842464
# 3                                           0.194097
# 4                                           0.458447
#
#    AreaOccupied_AreaOccupied_cells                                plate_well  \
# 0                        1048837.0  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02
# 1                        1727139.0  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02
# 2                        2033063.0  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02
# 3                        1085927.0  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02
# 4                        1792308.0  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02
#
#    Count_nuclei
# 0          74.0
# 1         123.0
# 2         148.0
# 3          67.0
# 4         130.0
#
# [5 rows x 2185 columns]

# %% [markdown]
# ## Save the combined data

# %%
dfQC.to_csv("{}/colo44_QC_filtered_Median.csv".format(OutputDir), sep=";")
