# %%
import os
import umap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.text import Text
import seaborn as sns; sns.set_style("white")
import umap.plot
# %matplotlib inline
os.getcwd()
# Out:
# '/Users/chririn/Documents/Code/2D_analysis_v2'

# %%
BaseDir = "./results/"

# %%
# Import feature data after QC
selected_df = pd.read_csv("{}colopaint44_selected_data_notMAD.csv".format(BaseDir), sep=";", index_col=0)
ListOfMetadata = list(selected_df.columns[selected_df.columns.str.contains("Metadata_")])
selected_df.head(1)
df_toplot = selected_df

# %%
df_toplot['Metadata_cmpd_conc'].loc[(df_toplot['Metadata_cmpd'] == '[dmso]')] = 0.0001
training_data = df_toplot.drop(ListOfMetadata, axis=1).to_numpy()
# Out:
# /var/folders/bx/43bwk4n57dj9446w1ddn_7t40000gn/T/ipykernel_89222/2324493696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_toplot['Metadata_cmpd_conc'].loc[(df_toplot['Metadata_cmpd'] == '[dmso]')] = 0.0001

# %%
## UMAP

reducer = umap.UMAP(n_components=2, n_neighbors=15, min_dist= 0.1, random_state=42)
embedding = reducer.fit_transform(training_data)

fig = plt.figure()
ax = sns.scatterplot(
    x=embedding[:, 0],
    y=embedding[:, 1],
    hue=df_toplot.Metadata_moa,
    alpha=(0.7),
    marker="o",
    #size=df_toplot["Metadata_cmpd_conc"],
    #palette=pal,
    legend=False
    )

plt.title('All concentrations')
# Out:
# Text(0.5, 1.0, 'All concentrations')

# %%
## UMAP

reducer = umap.UMAP(n_components=2, n_neighbors=15, min_dist= 0.1, random_state=42)
embedding = reducer.fit_transform(training_data)

fig = plt.figure()
ax = sns.scatterplot(
    x=embedding[:, 0],
    y=embedding[:, 1],
    hue=df_toplot.Metadata_moa,
    alpha=(0.7),
    marker="o",
    #size=df_toplot["Metadata_cmpd_conc"],
    #palette=pal,
    legend=False
    )

ax = sns.scatterplot(
    x=embedding[df_toplot['Metadata_pert_type'] == 'negcon', 0],
    y=embedding[df_toplot['Metadata_pert_type'] == 'negcon', 1],
    c='black',
    alpha=(0.7),
    marker="o",
    #palette=pal,
    legend=False
    )

plt.title('All concentrations')
# Out:
# Text(0.5, 1.0, 'All concentrations')

# %%
## UMAP

subsetDf = df_toplot[df_toplot['Metadata_cmpd_conc'] != 0.00833]
subsetDf = subsetDf[subsetDf['Metadata_cmpd_conc'] != 0.03330] # Remove lowest concentrations
training_data_subset = subsetDf.drop(ListOfMetadata, axis=1).to_numpy()


reducer = umap.UMAP(n_components=2, n_neighbors=30, min_dist= 0.1, random_state=42)
embedding = reducer.fit_transform(training_data_subset)

fig = plt.figure()
ax = sns.scatterplot(
    x=embedding[:, 0],
    y=embedding[:, 1],
    hue=subsetDf.Metadata_moa,
    alpha=(0.7),
    marker="o",
    #size=df_toplot["Metadata_cmpd_conc"],
    #palette=pal,
    legend=False
    )

plt.title('Subset of concentrations')
# Out:
# Text(0.5, 1.0, 'Subset of concentrations')

# %%
## UMAP

subsetDf = df_toplot[df_toplot['Metadata_cmpd_conc'] != 0.00833]
subsetDf = subsetDf[subsetDf['Metadata_cmpd_conc'] != 0.03330] # Remove lowest concentrations
training_data_subset = subsetDf.drop(ListOfMetadata, axis=1).to_numpy()


reducer = umap.UMAP(n_components=2, n_neighbors=30, min_dist= 0.1, random_state=42)
embedding = reducer.fit_transform(training_data_subset)

fig = plt.figure()
ax = sns.scatterplot(
    x=embedding[:, 0],
    y=embedding[:, 1],
    hue=subsetDf.Metadata_moa,
    alpha=(0.7),
    marker="o",
    #size=df_toplot["Metadata_cmpd_conc"],
    #palette=pal,
    legend=False
    )

#fig = plt.figure()
plt.title('Subset of concentrations')

ax = sns.scatterplot(
    x=embedding[subsetDf['Metadata_pert_type'] == 'negcon', 0],
    y=embedding[subsetDf['Metadata_pert_type'] == 'negcon', 1],
    c='black',
    alpha=(0.7),
    marker="o",
    #palette=pal,
    legend=False
    )

plt.title('Subset of concentrations')
# Out:
# Text(0.5, 1.0, 'Subset of concentrations')

# %%
## UMAP

subsetDf = df_toplot[df_toplot['Metadata_cmpd_conc'] != 0.00833]
subsetDf = subsetDf[subsetDf['Metadata_cmpd_conc'] != 0.03330] # Remove lowest concentrations
subsetDf = subsetDf[subsetDf['Metadata_cmpd_conc'] != 0.1]
training_data_subset = subsetDf.drop(ListOfMetadata, axis=1).to_numpy()


reducer = umap.UMAP(n_components=2, n_neighbors=24, min_dist= 0.1, random_state=42)
embedding = reducer.fit_transform(training_data_subset)

fig = plt.figure()
ax = sns.scatterplot(
    x=embedding[:, 0],
    y=embedding[:, 1],
    hue=subsetDf.Metadata_moa,
    alpha=(0.7),
    marker="o",
    #size=df_toplot["Metadata_cmpd_conc"],
    #palette=pal,
    legend=False
    )

#fig = plt.figure()
plt.title('Subset of concentrations')

ax = sns.scatterplot(
    x=embedding[subsetDf['Metadata_pert_type'] == 'negcon', 0],
    y=embedding[subsetDf['Metadata_pert_type'] == 'negcon', 1],
    c='black',
    alpha=(0.7),
    marker="o",
    #palette=pal,
    legend=False
    )

# %%
## UMAP

subsetDf = df_toplot[df_toplot['Metadata_cmpd_conc'] != 0.00833]
subsetDf = subsetDf[subsetDf['Metadata_cmpd_conc'] != 0.03330] # Remove lowest concentrations
subsetDf = subsetDf[subsetDf['Metadata_cmpd_conc'] != 0.1]
subsetDf = subsetDf[subsetDf['Metadata_cmpd_conc'] != 0.333]
training_data_subset = subsetDf.drop(ListOfMetadata, axis=1).to_numpy()


reducer = umap.UMAP(n_components=2, n_neighbors=23, min_dist= 0.3, random_state=42)
embedding = reducer.fit_transform(training_data_subset)

fig = plt.figure()
ax = sns.scatterplot(
    x=embedding[:, 0],
    y=embedding[:, 1],
    hue=subsetDf.Metadata_moa,
    alpha=(0.7),
    marker="o",
    #size=df_toplot["Metadata_cmpd_conc"],
    #palette=pal,
    #legend=False
    )
plt.legend(bbox_to_anchor=(2.7, 1),loc='upper right')
#fig = plt.figure()
plt.title('Subset of concentrations')

ax = sns.scatterplot(
    x=embedding[subsetDf['Metadata_pert_type'] == 'negcon', 0],
    y=embedding[subsetDf['Metadata_pert_type'] == 'negcon', 1],
    c='black',
    alpha=(0.7),
    marker="o",
    #palette=pal,
    legend=False
    )
