# %%
import os
import pandas as pd 
#import numpy as np

os.getcwd()
# Out:
# '/Users/chririn/Documents/Code/2D_analysis_v2'

# %%
OutputDir = "results" # Where do you want to save the merged data csv? 
if not os.path.exists(OutputDir):
    os.makedirs(OutputDir)

# %% [markdown]
# Change these codes to: 1) Remove flagged images, 2) Adjust the metadata of my plate.

# %% [markdown]
# ## Read Feature and Layout data
# Metadata matters!

# %%
# Feature data 
BaseDir = "./ImageMeanFeatures/"
df = pd.read_csv("{}/ImageMeansAllPlates.csv".format(BaseDir), sep=";", index_col=0)
df.head(1)
# Out:
#                                             ImageNumber_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                 1.0
#
#                                             ObjectNumber_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1            42.710843
#
#                                             Metadata_Site_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                   1.0
#
#                                             AreaShape_Area_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1             2227.26506
#
#                                             AreaShape_BoundingBoxArea_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                       3130.746988
#
#                                             AreaShape_BoundingBoxMaximum_X_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                            1100.855422
#
#                                             AreaShape_BoundingBoxMaximum_Y_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                             846.096386
#
#                                             AreaShape_BoundingBoxMinimum_X_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                            1046.445783
#
#                                             AreaShape_BoundingBoxMinimum_Y_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                             790.421687
#
#                                             AreaShape_Center_X_nuclei  ...  \
# ImageID                                                                ...
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                1073.186464  ...
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_0_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           -0.35958
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_2_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.565058
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_4_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.439547
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_6_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.053552
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_8_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.745592
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_1_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.319574
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_3_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.182558
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_5_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.277881
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_7_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.151311
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_9_cytoplasm
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.090146
#
# [1 rows x 2187 columns]

# %%
# Some necessary adaptations on the dataframe
df.drop(['Metadata_Site_nuclei','Metadata_Site_cytoplasm','Metadata_Site_cells','ImageNumber_cells','ImageNumber_cytoplasm', 'ImageNumber_nuclei'], axis=1, inplace=True) # "ImageNumber_nuclei": is 1 across the entire plate, it originates in the pipelineGUI where we run batches of 1 image only -> every image will be no. 1, "Metadata_Site_nuclei": have a new column now. 
df["plate_well"] = df.index.str[0:-2] # Well identifier accross an entire batch
df.head(1)
# Out:
#                                             ObjectNumber_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1            42.710843
#
#                                             AreaShape_Area_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1             2227.26506
#
#                                             AreaShape_BoundingBoxArea_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                       3130.746988
#
#                                             AreaShape_BoundingBoxMaximum_X_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                            1100.855422
#
#                                             AreaShape_BoundingBoxMaximum_Y_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                             846.096386
#
#                                             AreaShape_BoundingBoxMinimum_X_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                            1046.445783
#
#                                             AreaShape_BoundingBoxMinimum_Y_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                             790.421687
#
#                                             AreaShape_Center_X_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                1073.186464
#
#                                             AreaShape_Center_Y_nuclei  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                 817.888984
#
#                                             AreaShape_Compactness_nuclei  ...  \
# ImageID                                                                   ...
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                      1.234718  ...
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_2_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.565058
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_4_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.439547
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_6_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.053552
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_8_8_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.745592
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_1_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.319574
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_3_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.182558
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_5_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                          -0.277881
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_7_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.151311
#
#                                             RadialDistribution_ZernikePhase_illumSYTO_9_9_cytoplasm  \
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1                                           0.090146
#
#                                                                           plate_well
# ImageID
# colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02
#
# [1 rows x 2182 columns]

# %%
List = df.columns.values

# %% [markdown]
# ## Remove QC flagged images

# %%
QC = pd.read_csv("./QC/colo44_Flags.csv", sep=";", index_col=0)
QC["ImageID"] = (
    QC["Metadata_Barcode"]
    + "_"
    + QC["Metadata_Well"]
    + "_"
    + QC["Metadata_Site"].astype(str)
)
QC.head(3)
# Out:
#                        Metadata_Barcode Metadata_Well  Metadata_Site  \
# 0  colo44-v1-FA-P017365-CACO2-48h-P1-L1           B02              1
# 1  colo44-v1-FA-P017365-CACO2-48h-P1-L1           B02              2
# 2  colo44-v1-FA-P017365-CACO2-48h-P1-L1           B02              3
#
#    Count_nuclei  ImageQuality_PercentMaximal_CONC  \
# 0          74.0                          0.004994
# 1         123.0                          0.004951
# 2         148.0                          0.003601
#
#    ImageQuality_PercentMaximal_HOECHST  ImageQuality_PercentMaximal_MITO  \
# 0                             0.000021                          0.198667
# 1                             0.000021                          0.003558
# 2                             0.000021                          0.000343
#
#    ImageQuality_PercentMaximal_PHAandWGA  ImageQuality_PercentMaximal_SYTO  \
# 0                               0.090964                          0.292245
# 1                               0.052533                          0.110747
# 2                               0.080097                          0.143497
#
#    OutlierScaled_FocusScore_-2.0_5.0  OutlierScaled_MeanIntensity_-2.2_4.0  \
# 0                                  0                                     0
# 1                                  0                                     0
# 2                                  0                                     0
#
#    OutlierScaled_PercentMaximal_-2.0_7.5  \
# 0                                      0
# 1                                      0
# 2                                      0
#
#    OutlierScaled_PowerLogLogSlope_-3.5_3.5  \
# 0                                        0
# 1                                        0
# 2                                        0
#
#    OutlierScaled_StdIntensity_-3.3_3.3  Total  Total.1  \
# 0                                    0      0        0
# 1                                    0      0        0
# 2                                    0      0        0
#
#                                       ImageID
# 0  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1
# 1  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_2
# 2  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_3

# %%
dfQC = df.merge(QC[['ImageID', 'Total', 'Count_nuclei']], left_on = 'ImageID', right_on = 'ImageID', how = 'left') 
dfQC = dfQC[dfQC['Total'] == 0]
dfQC.drop(["Total"], axis=1, inplace=True)
dfQC.reset_index(drop=True, inplace=True)
dfQC.head()
# Out:
#                                       ImageID  ObjectNumber_nuclei  \
# 0  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_1            42.710843
# 1  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_2            68.000000
# 2  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_3            82.500000
# 3  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_4            45.788889
# 4  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02_5            73.000000
#
#    AreaShape_Area_nuclei  AreaShape_BoundingBoxArea_nuclei  \
# 0            2227.265060                       3130.746988
# 1            2508.688889                       3493.725926
# 2            2573.036585                       3535.359756
# 3            2545.466667                       3564.800000
# 4            2634.662069                       3752.917241
#
#    AreaShape_BoundingBoxMaximum_X_nuclei  \
# 0                            1100.855422
# 1                            1115.948148
# 2                            1148.975610
# 3                            1313.044444
# 4                             932.441379
#
#    AreaShape_BoundingBoxMaximum_Y_nuclei  \
# 0                             846.096386
# 1                            1229.451852
# 2                             939.597561
# 3                            1297.022222
# 4                            1242.165517
#
#    AreaShape_BoundingBoxMinimum_X_nuclei  \
# 0                            1046.445783
# 1                            1059.333333
# 2                            1090.658537
# 3                            1252.566667
# 4                             871.924138
#
#    AreaShape_BoundingBoxMinimum_Y_nuclei  AreaShape_Center_X_nuclei  \
# 0                             790.421687                1073.186464
# 1                            1170.125926                1087.182142
# 2                             880.682927                1119.187434
# 3                            1240.500000                1282.069826
# 4                            1181.862069                 901.836390
#
#    AreaShape_Center_Y_nuclei  ...  \
# 0                 817.888984  ...
# 1                1199.125669  ...
# 2                 909.666397  ...
# 3                1268.171360  ...
# 4                1211.607624  ...
#
#    RadialDistribution_ZernikePhase_illumSYTO_8_4_cytoplasm  \
# 0                                          -0.439547
# 1                                          -0.001519
# 2                                          -0.258560
# 3                                           0.828341
# 4                                           0.111713
#
#    RadialDistribution_ZernikePhase_illumSYTO_8_6_cytoplasm  \
# 0                                          -0.053552
# 1                                           0.236127
# 2                                           0.147393
# 3                                          -0.124533
# 4                                          -0.452476
#
#    RadialDistribution_ZernikePhase_illumSYTO_8_8_cytoplasm  \
# 0                                           0.745592
# 1                                           0.007504
# 2                                          -0.208259
# 3                                           0.160291
# 4                                           0.137056
#
#    RadialDistribution_ZernikePhase_illumSYTO_9_1_cytoplasm  \
# 0                                           0.319574
# 1                                           0.081132
# 2                                          -0.093694
# 3                                           0.083505
# 4                                           0.327996
#
#    RadialDistribution_ZernikePhase_illumSYTO_9_3_cytoplasm  \
# 0                                           0.182558
# 1                                          -0.051667
# 2                                          -0.168275
# 3                                           0.414014
# 4                                          -0.482307
#
#    RadialDistribution_ZernikePhase_illumSYTO_9_5_cytoplasm  \
# 0                                          -0.277881
# 1                                          -0.160308
# 2                                           0.051386
# 3                                           0.089787
# 4                                          -0.053043
#
#    RadialDistribution_ZernikePhase_illumSYTO_9_7_cytoplasm  \
# 0                                           0.151311
# 1                                           0.265595
# 2                                           0.156844
# 3                                          -0.301948
# 4                                           0.417122
#
#    RadialDistribution_ZernikePhase_illumSYTO_9_9_cytoplasm  \
# 0                                           0.090146
# 1                                           0.178329
# 2                                           0.442318
# 3                                           0.398105
# 4                                           0.072934
#
#                                  plate_well  Count_nuclei
# 0  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02          74.0
# 1  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02         123.0
# 2  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02         148.0
# 3  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02          67.0
# 4  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02         130.0
#
# [5 rows x 2184 columns]

# %% [markdown]
# ## Save the combined data

# %%
dfQC.to_csv("{}/colo44_QC_filtered_Mean.csv".format(OutputDir), sep=";")
