# %%
import os
import pandas as pd 
import numpy as np
os.getcwd()
# Out:
# '/Users/chririn/Documents/Code'

# %%
OutputDir = input("Enter name for output folder: ")  #
if not os.path.exists(OutputDir):
    os.makedirs(OutputDir)

# %%
dfZscores = pd.read_csv("./2D_analysis/results2/dfZscores4.csv", sep=";")
dfZscores = dfZscores.drop(dfZscores.columns[[0]], axis=1)  # df.columns is zero-based pd.Index
dfZscores.head()
# Out:
#    AreaShape_Area_nuclei  AreaShape_BoundingBoxArea_nuclei  \
# 0              -0.982456                         -1.876923
# 1              -0.561404                          0.548718
# 2              -0.451128                          0.087179
# 3               0.205514                          0.728205
# 4              -0.528822                          0.064103
#
#    AreaShape_BoundingBoxMaximum_X_nuclei  \
# 0                              -0.049107
# 1                              -1.138393
# 2                               0.156250
# 3                              -1.397321
# 4                               2.691964
#
#    AreaShape_BoundingBoxMaximum_Y_nuclei  \
# 0                               0.216102
# 1                              -0.105932
# 2                               4.156780
# 3                               2.622881
# 4                              -1.872881
#
#    AreaShape_BoundingBoxMinimum_X_nuclei  \
# 0                               0.155902
# ...

# %% [markdown]
# #### Viability score

# %%
ListOfData = list(dfZscores.columns.values)

# %%
BaseDir = '/Users/chririn/Documents/Data/colo44/results/'

# %%
# Load viabilty data
dfPerWell = pd.read_csv("./2D_analysis/results2/dfPerWell1.csv", sep=";")
dfPerWell = dfPerWell.drop(dfPerWell.columns[[0]], axis=1)  # df.columns is zero-based pd.Index
dfPerWell.head()
# Out:
#                                   plateWell  AreaShape_Area_nuclei  \
# 0  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B02                2052.50
# 1  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B04                2094.50
# 2  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B05                2105.50
# 3  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B06                2171.00
# 4  colo44-v1-FA-P017365-CACO2-48h-P1-L1_B07                2097.75
#
#    AreaShape_BoundingBoxArea_nuclei  AreaShape_BoundingBoxMaximum_X_nuclei  \
# 0                           2866.00                                 1131.0
# 1                           3102.50                                 1070.0
# 2                           3057.50                                 1142.5
# 3                           3120.00                                 1055.5
# 4                           3055.25                                 1284.5
#
#    AreaShape_BoundingBoxMaximum_Y_nuclei  \
# 0                                1125.00
# ...

# %%
theseFeatures = ListOfData[-6:]

# %%
dfViability = dfPerWell[theseFeatures]

# %%
dfViability.to_csv("2D_analysis/results2/viability_scores3.csv", sep=";")
